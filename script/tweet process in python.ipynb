# %%
import os
import pandas as pd
import glob

# %%
out_dir="/nfs/turbo/seas-zhukai/phenology/Twitter/"
category="pollen"
year="2022"
month="04"
day="01"
all_files = glob.glob(os.path.join(out_dir,category+"/","CSV/",year+"/",month+"/",day+"/")+ "*.csv")
df = pd.concat((pd.read_csv(f, sep='\t', escapechar='\\') for f in all_files))
df.head(10)
# Out:
#                        created_at                   id      screen_name  \
# 0  Fri Apr 01 19:42:22 +0000 2022  1302727263297957888  SonyaCa76359881
# 1  Fri Apr 01 23:20:35 +0000 2022  1473914864074645504       daddy21805
# 2  Fri Apr 01 22:25:32 +0000 2022   888420941033861121      MikeSuskoWx
# 3  Fri Apr 01 20:58:09 +0000 2022   787787748836937728      Tarampratt6
# 4  Fri Apr 01 19:31:02 +0000 2022  1477437700445818884     SissyKelly74
# 5  Fri Apr 01 23:20:27 +0000 2022             23553315         xobabyox
# 6  Fri Apr 01 20:23:35 +0000 2022            180365358       CarolinaWx
# 7  Fri Apr 01 22:04:14 +0000 2022   959578867064164352  ImperiusWrecked
# 8  Fri Apr 01 19:27:34 +0000 2022  1139987615212539906   yubyubcommandr
# 9  Fri Apr 01 23:08:36 +0000 2022  1425917253644537857     Taku73792578
#
#                                          description  \
# 0        Everyday spent laughing is a day not wasted
# 1                                    taken ❤️ rivers
# ...

# %%
df['full_text'].iloc[8]
# Out:
# '@missjenmichelle might be pollen? might be anything tbh. I feel like we’re in a weird place with our immune systems with masking and unmasking and masking'

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install twint
# !{sys.executable} -m pip install nest_asyncio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import nest_asyncio

nest_asyncio.apply()
import twint

# %%
t = twint.Config()

# %%
t.Limit = 1

t.Username = 'SYiluan'

t.Pandas = True

twint.run.Following(t)

follow_df = twint.storage.panda.User_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1399892/121065791.py in <module>
#       5 t.Pandas = True
#       6
# ----> 7 twint.run.Following(t)
#       8
#       9 follow_df = twint.storage.panda.User_df
#
# ~/.local/lib/python3.9/site-packages/twint/run.py in Following(config)
#     263     config.Favorites = False
#     264     config.TwitterSearch = False
# --> 265     run(config)
#     266     if config.Pandas_au:
#     267         storage.panda._autoget("following")
#
# ~/.local/lib/python3.9/site-packages/twint/run.py in run(config, callback)
#     224         raise
#     225
# --> 226     get_event_loop().run_until_complete(Twint(config).main(callback))
#     227
#     228 def Favorites(config):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/nest_asyncio.py in run_until_complete(self, future)
# ...

# %%
follow_df

# %%
from datetime import date, timedelta
import twint
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()

c.Username = 'jack'
c.Since = '2021-02-17 00:00:00'
c.Until = '2021-02-18 00:00:00'
c.Pandas = True

twint.run.Search(c)
# Out:
# CRITICAL:root:twint.get:User:
# CRITICAL:root:twint.get:User:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/twint/get.py in Response(session, url, params)
#     147     with timeout(120):
# --> 148         async with session.get(url, ssl=True, params=params, proxy=httpproxy) as response:
#     149             return await response.text()
#
# ~/.local/lib/python3.9/site-packages/aiohttp/client.py in __aenter__(self)
#    1140     async def __aenter__(self) -> _RetType:
# -> 1141         self._resp = await self._coro
#    1142         return self._resp
#
# ...
